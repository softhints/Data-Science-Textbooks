# %% [markdown]
# # Styling
#
# * [Reference: Style](https://pandas.pydata.org/docs/reference/style.html)
# * [User Guide: Styling](https://pandas.pydata.org/docs/user_guide/style.html)

# %% [markdown]
# ## Data

# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[3, 3] = np.nan
df.iloc[0, 2] = np.nan
df
# Out:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720

# %% [markdown]
# ## B: Beginner

# %% [markdown]
# ### B1:
# Can you highlight negative values in red? (as shown below)
#
# ![](../../../images/Pandas/style_b1_highlight_negative.png)

# %%
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

df.style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
# #T_9f7ec_row0_col0,#T_9f7ec_row0_col1,#T_9f7ec_row0_col2,#T_9f7ec_row1_col0,#T_9f7ec_row1_col3,#T_9f7ec_row1_col4,#T_9f7ec_row2_col0,#T_9f7ec_row2_col2,#T_9f7ec_row2_col3,#T_9f7ec_row2_col4,#T_9f7ec_row3_col0,#T_9f7ec_row3_col1,#T_9f7ec_row3_col2,#T_9f7ec_row3_col3,#T_9f7ec_row3_col4,#T_9f7ec_row4_col0,#T_9f7ec_row4_col1,#T_9f7ec_row4_col2,#T_9f7ec_row4_col3,#T_9f7ec_row4_col4,#T_9f7ec_row5_col0,#T_9f7ec_row5_col2,#T_9f7ec_row5_col3,#T_9f7ec_row6_col0,#T_9f7ec_row6_col1,#T_9f7ec_row6_col2,#T_9f7ec_row6_col4,#T_9f7ec_row7_col0,#T_9f7ec_row7_col1,#T_9f7ec_row7_col2,#T_9f7ec_row7_col4,#T_9f7ec_row8_col0,#T_9f7ec_row8_col1,#T_9f7ec_row8_col3,#T_9f7ec_row9_col0,#T_9f7ec_row9_col2,#T_9f7ec_row9_col4{
#             color:  black;
#         }#T_9f7ec_row0_col3,#T_9f7ec_row0_col4,#T_9f7ec_row1_col1,#T_9f7ec_row1_col2,#T_9f7ec_row2_col1,#T_9f7ec_row5_col1,#T_9f7ec_row5_col4,#T_9f7ec_row6_col3,#T_9f7ec_row7_col3,#T_9f7ec_row8_col2,#T_9f7ec_row8_col4,#T_9f7ec_row9_col1,#T_9f7ec_row9_col3{
#             color:  red;
#         }</style><table id="T_9f7ec_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f7ec_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9f7ec_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_9f7ec_row0_col1" class="data row0 col1" >1.329212</td>
#                         <td id="T_9f7ec_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_9f7ec_row0_col3" class="data row0 col3" >-0.316280</td>
#                         <td id="T_9f7ec_row0_col4" class="data row0 col4" >-0.990810</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9f7ec_row1_col0" class="data row1 col0" >2.000000</td>
#                         <td id="T_9f7ec_row1_col1" class="data row1 col1" >-1.070816</td>
#                         <td id="T_9f7ec_row1_col2" class="data row1 col2" >-1.438713</td>
#                         <td id="T_9f7ec_row1_col3" class="data row1 col3" >0.564417</td>
#                         <td id="T_9f7ec_row1_col4" class="data row1 col4" >0.295722</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9f7ec_row2_col0" class="data row2 col0" >3.000000</td>
#                         <td id="T_9f7ec_row2_col1" class="data row2 col1" >-1.626404</td>
#                         <td id="T_9f7ec_row2_col2" class="data row2 col2" >0.219565</td>
#                         <td id="T_9f7ec_row2_col3" class="data row2 col3" >0.678805</td>
#                         <td id="T_9f7ec_row2_col4" class="data row2 col4" >1.889273</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9f7ec_row3_col0" class="data row3 col0" >4.000000</td>
#                         <td id="T_9f7ec_row3_col1" class="data row3 col1" >0.961538</td>
#                         <td id="T_9f7ec_row3_col2" class="data row3 col2" >0.104011</td>
#                         <td id="T_9f7ec_row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_9f7ec_row3_col4" class="data row3 col4" >0.850229</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9f7ec_row4_col0" class="data row4 col0" >5.000000</td>
#                         <td id="T_9f7ec_row4_col1" class="data row4 col1" >1.453425</td>
#                         <td id="T_9f7ec_row4_col2" class="data row4 col2" >1.057737</td>
#                         <td id="T_9f7ec_row4_col3" class="data row4 col3" >0.165562</td>
#                         <td id="T_9f7ec_row4_col4" class="data row4 col4" >0.515018</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9f7ec_row5_col0" class="data row5 col0" >6.000000</td>
#                         <td id="T_9f7ec_row5_col1" class="data row5 col1" >-1.336936</td>
#                         <td id="T_9f7ec_row5_col2" class="data row5 col2" >0.562861</td>
#                         <td id="T_9f7ec_row5_col3" class="data row5 col3" >1.392855</td>
#                         <td id="T_9f7ec_row5_col4" class="data row5 col4" >-0.063328</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9f7ec_row6_col0" class="data row6 col0" >7.000000</td>
#                         <td id="T_9f7ec_row6_col1" class="data row6 col1" >0.121668</td>
#                         <td id="T_9f7ec_row6_col2" class="data row6 col2" >1.207603</td>
#                         <td id="T_9f7ec_row6_col3" class="data row6 col3" >-0.002040</td>
#                         <td id="T_9f7ec_row6_col4" class="data row6 col4" >1.627796</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9f7ec_row7_col0" class="data row7 col0" >8.000000</td>
#                         <td id="T_9f7ec_row7_col1" class="data row7 col1" >0.354493</td>
#                         <td id="T_9f7ec_row7_col2" class="data row7 col2" >1.037528</td>
#                         <td id="T_9f7ec_row7_col3" class="data row7 col3" >-0.385684</td>
#                         <td id="T_9f7ec_row7_col4" class="data row7 col4" >0.519818</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9f7ec_row8_col0" class="data row8 col0" >9.000000</td>
#                         <td id="T_9f7ec_row8_col1" class="data row8 col1" >1.686583</td>
#                         <td id="T_9f7ec_row8_col2" class="data row8 col2" >-1.325963</td>
#                         <td id="T_9f7ec_row8_col3" class="data row8 col3" >1.428984</td>
#                         <td id="T_9f7ec_row8_col4" class="data row8 col4" >-2.089354</td>
#             </tr>
#             <tr>
#                         <th id="T_9f7ec_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9f7ec_row9_col0" class="data row9 col0" >10.000000</td>
#                         <td id="T_9f7ec_row9_col1" class="data row9 col1" >-0.129820</td>
#                         <td id="T_9f7ec_row9_col2" class="data row9 col2" >0.631523</td>
#                         <td id="T_9f7ec_row9_col3" class="data row9 col3" >-0.586538</td>
#                         <td id="T_9f7ec_row9_col4" class="data row9 col4" >0.290720</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### B2:
# Can you highlight maxiumum value in the whole DataFrame?

# %% [markdown]
# ### B3:
# Can you highlight maxiumum value per column? row?

# %% [markdown]
# ## A: Advanced

# %% [markdown]
# ### A1:
# Can you highlight columns based on the column name?
# Sample color map:
#
# `{'A':'cyan', 'B':'lightblue', 'C':'lightyellow', 'D':'salmon', 'E':'lightgreen'}`
#
# ![](../../../images/Pandas/style_a1_color_columns.png)

# %%
coldict = {'A':'cyan', 'B':'lightblue', 'C':'lightyellow', 'D':'salmon', 'E':'lightgreen'}

def highlight_cols(s, coldict):
    if s.name in coldict.keys():
        return ['background-color: {}'.format(coldict[s.name])] * len(s)
    return [''] * len(s)

df.style.apply(highlight_cols, coldict=coldict)
# Out:
# <style  type="text/css" >
# #T_0d94a_row0_col0,#T_0d94a_row1_col0,#T_0d94a_row2_col0,#T_0d94a_row3_col0,#T_0d94a_row4_col0,#T_0d94a_row5_col0,#T_0d94a_row6_col0,#T_0d94a_row7_col0,#T_0d94a_row8_col0,#T_0d94a_row9_col0{
#             background-color:  cyan;
#         }#T_0d94a_row0_col1,#T_0d94a_row1_col1,#T_0d94a_row2_col1,#T_0d94a_row3_col1,#T_0d94a_row4_col1,#T_0d94a_row5_col1,#T_0d94a_row6_col1,#T_0d94a_row7_col1,#T_0d94a_row8_col1,#T_0d94a_row9_col1{
#             background-color:  lightblue;
#         }#T_0d94a_row0_col2,#T_0d94a_row1_col2,#T_0d94a_row2_col2,#T_0d94a_row3_col2,#T_0d94a_row4_col2,#T_0d94a_row5_col2,#T_0d94a_row6_col2,#T_0d94a_row7_col2,#T_0d94a_row8_col2,#T_0d94a_row9_col2{
#             background-color:  lightyellow;
#         }#T_0d94a_row0_col3,#T_0d94a_row1_col3,#T_0d94a_row2_col3,#T_0d94a_row3_col3,#T_0d94a_row4_col3,#T_0d94a_row5_col3,#T_0d94a_row6_col3,#T_0d94a_row7_col3,#T_0d94a_row8_col3,#T_0d94a_row9_col3{
#             background-color:  salmon;
#         }#T_0d94a_row0_col4,#T_0d94a_row1_col4,#T_0d94a_row2_col4,#T_0d94a_row3_col4,#T_0d94a_row4_col4,#T_0d94a_row5_col4,#T_0d94a_row6_col4,#T_0d94a_row7_col4,#T_0d94a_row8_col4,#T_0d94a_row9_col4{
#             background-color:  lightgreen;
#         }</style><table id="T_0d94a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d94a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0d94a_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0d94a_row0_col1" class="data row0 col1" >1.329212</td>
#                         <td id="T_0d94a_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_0d94a_row0_col3" class="data row0 col3" >-0.316280</td>
#                         <td id="T_0d94a_row0_col4" class="data row0 col4" >-0.990810</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0d94a_row1_col0" class="data row1 col0" >2.000000</td>
#                         <td id="T_0d94a_row1_col1" class="data row1 col1" >-1.070816</td>
#                         <td id="T_0d94a_row1_col2" class="data row1 col2" >-1.438713</td>
#                         <td id="T_0d94a_row1_col3" class="data row1 col3" >0.564417</td>
#                         <td id="T_0d94a_row1_col4" class="data row1 col4" >0.295722</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0d94a_row2_col0" class="data row2 col0" >3.000000</td>
#                         <td id="T_0d94a_row2_col1" class="data row2 col1" >-1.626404</td>
#                         <td id="T_0d94a_row2_col2" class="data row2 col2" >0.219565</td>
#                         <td id="T_0d94a_row2_col3" class="data row2 col3" >0.678805</td>
#                         <td id="T_0d94a_row2_col4" class="data row2 col4" >1.889273</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0d94a_row3_col0" class="data row3 col0" >4.000000</td>
#                         <td id="T_0d94a_row3_col1" class="data row3 col1" >0.961538</td>
#                         <td id="T_0d94a_row3_col2" class="data row3 col2" >0.104011</td>
#                         <td id="T_0d94a_row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_0d94a_row3_col4" class="data row3 col4" >0.850229</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0d94a_row4_col0" class="data row4 col0" >5.000000</td>
#                         <td id="T_0d94a_row4_col1" class="data row4 col1" >1.453425</td>
#                         <td id="T_0d94a_row4_col2" class="data row4 col2" >1.057737</td>
#                         <td id="T_0d94a_row4_col3" class="data row4 col3" >0.165562</td>
#                         <td id="T_0d94a_row4_col4" class="data row4 col4" >0.515018</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0d94a_row5_col0" class="data row5 col0" >6.000000</td>
#                         <td id="T_0d94a_row5_col1" class="data row5 col1" >-1.336936</td>
#                         <td id="T_0d94a_row5_col2" class="data row5 col2" >0.562861</td>
#                         <td id="T_0d94a_row5_col3" class="data row5 col3" >1.392855</td>
#                         <td id="T_0d94a_row5_col4" class="data row5 col4" >-0.063328</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0d94a_row6_col0" class="data row6 col0" >7.000000</td>
#                         <td id="T_0d94a_row6_col1" class="data row6 col1" >0.121668</td>
#                         <td id="T_0d94a_row6_col2" class="data row6 col2" >1.207603</td>
#                         <td id="T_0d94a_row6_col3" class="data row6 col3" >-0.002040</td>
#                         <td id="T_0d94a_row6_col4" class="data row6 col4" >1.627796</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0d94a_row7_col0" class="data row7 col0" >8.000000</td>
#                         <td id="T_0d94a_row7_col1" class="data row7 col1" >0.354493</td>
#                         <td id="T_0d94a_row7_col2" class="data row7 col2" >1.037528</td>
#                         <td id="T_0d94a_row7_col3" class="data row7 col3" >-0.385684</td>
#                         <td id="T_0d94a_row7_col4" class="data row7 col4" >0.519818</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0d94a_row8_col0" class="data row8 col0" >9.000000</td>
#                         <td id="T_0d94a_row8_col1" class="data row8 col1" >1.686583</td>
#                         <td id="T_0d94a_row8_col2" class="data row8 col2" >-1.325963</td>
#                         <td id="T_0d94a_row8_col3" class="data row8 col3" >1.428984</td>
#                         <td id="T_0d94a_row8_col4" class="data row8 col4" >-2.089354</td>
#             </tr>
#             <tr>
#                         <th id="T_0d94a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0d94a_row9_col0" class="data row9 col0" >10.000000</td>
#                         <td id="T_0d94a_row9_col1" class="data row9 col1" >-0.129820</td>
#                         <td id="T_0d94a_row9_col2" class="data row9 col2" >0.631523</td>
#                         <td id="T_0d94a_row9_col3" class="data row9 col3" >-0.586538</td>
#                         <td id="T_0d94a_row9_col4" class="data row9 col4" >0.290720</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### A2:
# Can you color rows which index is divisible to 3 and 5?

# %% [markdown]
# ## M: Master

# %%
df_m = pd.DataFrame({'A': [12,6,8, 15], 'B': [3,4,1, 7]})

# %% [markdown]
# ### M1
# Can you add new column B to A % and style it as follows(bar dependent on value lenght):
#
# Can you change the scale to 100%?
#
# ![](../../../images/Pandas/style_m1_styling_bar.png)

# %%
df_m['B/A %'] = df_m['B'] / df_m['A'] * 100
df_m.style.bar(subset=["B/A %"], color='#FFA07A')
# Out:
# <style  type="text/css" >
# #T_53e51_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 23.1%, transparent 23.1%);
#         }#T_53e51_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 100.0%, transparent 100.0%);
#         }#T_53e51_row2_col2{
#             width:  10em;
#              height:  80%;
#         }#T_53e51_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 63.1%, transparent 63.1%);
#         }</style><table id="T_53e51_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >B/A %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_53e51_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_53e51_row0_col0" class="data row0 col0" >12</td>
#                         <td id="T_53e51_row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_53e51_row0_col2" class="data row0 col2" >25.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_53e51_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_53e51_row1_col0" class="data row1 col0" >6</td>
#                         <td id="T_53e51_row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_53e51_row1_col2" class="data row1 col2" >66.666667</td>
#             </tr>
#             <tr>
#                         <th id="T_53e51_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_53e51_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_53e51_row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_53e51_row2_col2" class="data row2 col2" >12.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_53e51_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_53e51_row3_col0" class="data row3 col0" >15</td>
#                         <td id="T_53e51_row3_col1" class="data row3 col1" >7</td>
#                         <td id="T_53e51_row3_col2" class="data row3 col2" >46.666667</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### M2
# Can you add a new column which is sum of both A and B?
#
# Then style it by showing split based on the percent of which value from column A or B as shown below:
#
# ![](../../../images/Pandas/style_m1_styling_split_color.png)

# %%
def highlight_cols(x):
    df = x.copy()
    
    for i in df.iterrows():
        b = i[1].get('B')
        a = i[1].get('A')
        
        if a != 0:
            grad = b / a * 100
        else:
            grad = 0
        
        df.loc[i[0],['total']] = f'width:  10em; height:  80%; background: linear-gradient(to right, tomato {grad}%, lightblue {grad}%);'
        
    df.iloc[:,0:3] = ''
#     display(df)
    return df    

df_m['total'] = df_m['B'] + df_m['A']
df_m.style.apply(highlight_cols, axis=None)
# Out:
# <style  type="text/css" >
# #T_1aeca_row0_col3{
#             width:   10em;
#              height:   80%;
#              background:  linear-gradient(to right, tomato 25.0%, lightblue 25.0%);
#         }#T_1aeca_row1_col3{
#             width:   10em;
#              height:   80%;
#              background:  linear-gradient(to right, tomato 66.66666666666666%, lightblue 66.66666666666666%);
#         }#T_1aeca_row2_col3{
#             width:   10em;
#              height:   80%;
#              background:  linear-gradient(to right, tomato 12.5%, lightblue 12.5%);
#         }#T_1aeca_row3_col3{
#             width:   10em;
#              height:   80%;
#              background:  linear-gradient(to right, tomato 46.666666666666664%, lightblue 46.666666666666664%);
#         }</style><table id="T_1aeca_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >B/A %</th>        <th class="col_heading level0 col3" >total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1aeca_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1aeca_row0_col0" class="data row0 col0" >12</td>
#                         <td id="T_1aeca_row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_1aeca_row0_col2" class="data row0 col2" >25.000000</td>
#                         <td id="T_1aeca_row0_col3" class="data row0 col3" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_1aeca_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1aeca_row1_col0" class="data row1 col0" >6</td>
#                         <td id="T_1aeca_row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_1aeca_row1_col2" class="data row1 col2" >66.666667</td>
#                         <td id="T_1aeca_row1_col3" class="data row1 col3" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_1aeca_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1aeca_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_1aeca_row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_1aeca_row2_col2" class="data row2 col2" >12.500000</td>
#                         <td id="T_1aeca_row2_col3" class="data row2 col3" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_1aeca_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1aeca_row3_col0" class="data row3 col0" >15</td>
#                         <td id="T_1aeca_row3_col1" class="data row3 col1" >7</td>
#                         <td id="T_1aeca_row3_col2" class="data row3 col2" >46.666667</td>
#                         <td id="T_1aeca_row3_col3" class="data row3 col3" >22</td>
#             </tr>
#     </tbody></table>
